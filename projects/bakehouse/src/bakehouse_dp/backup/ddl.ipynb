# %%
# %sql
create catalog dev_dab

# %%
# %sql
create schema dev_dab.bronze;

# %%
# %sql
create schema dev_dab.silver;

# %%
# %sql
create schema dev_dab.gold;

# %%
# %sql
create volume dev_dab.bronze.volume

# %%
# %sql
drop table dev.bronze.event_log_dp_bakehouse;
drop table dev.bronze.franchises_raw_bronze;
drop table dev.bronze.sales_customers_bronze;
drop table dev.bronze.sales_transactions_bronze;
drop table dev.bronze.suppliers_invalid_bronze;
drop table dev.bronze.suppliers_raw_bronze;
drop table dev.silver.franchises_silver;
drop table dev.silver.sales_customers_silver;
drop table dev.silver.sales_transactions_silver;
drop table dev.silver.suppliers_silver;
